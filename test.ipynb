# %%
pip install qdrant-client
# Out:
# ...
#
#   Obtaining dependency information for qdrant-client from https://files.pythonhosted.org/packages/35/5e/8174c845707e60b60b65c58f01e40bbc1d8181b5ff6463f25df470509917/qdrant_client-1.14.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for portalocker<3.0.0,>=2.7.0 from https://files.pythonhosted.org/packages/9b/fb/a70a4214956182e0d7a9099ab17d50bfcba1056188e9b14f35b9e2b62a0d/portalocker-2.10.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for h2<5,>=3 from https://files.pythonhosted.org/packages/d0/9e/984486f2d0a0bd2b024bf4bc1c62688fcafa9e61991f041fb0e2def4a982/h2-4.2.0-py3-none-any.whl.metadata
#   Using cached h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Obtaining dependency information for hyperframe<7,>=6.1 from https://files.pythonhosted.org/packages/48/30/47d0bf6072f7252e6521f3447ccfa40b421b6824517f82854703d0f5a98b/hyperframe-6.1.0-py3-none-any.whl.metadata
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# ...

# %%
import sqlite3
import numpy as np
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PointStruct
import uuid
import ast

# Step 1: Connect to your SQLite file
conn = sqlite3.connect("C:\\Users\\Srujana\\Documents\\edu-companion\\assets\\ncert-vectors.db")
cursor = conn.cursor()

# Step 2: Connect to Qdrant
client = QdrantClient(host="localhost", port=6333)

# Step 3: Create or Recreate the collection
VECTOR_SIZE = 384  # Set this to match your actual embedding size
client.recreate_collection(
    collection_name="ncert-vectors",
    vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE)
)

# Step 4: Load all records from SQLite
cursor.execute("SELECT id, content, class, subject, chapter, page, embedding FROM vectors")
rows = cursor.fetchall()

points = []

for row in rows:
    row_id, content, class_, subject, chapter, page, embedding_blob = row

    # Convert blob to list of floats
    vector = np.frombuffer(embedding_blob, dtype=np.float32).tolist()

    metadata = {
        "content": content,
        "class": class_,
        "subject": subject,
        "chapter": chapter,
        "page": page
    }

    points.append(
        PointStruct(
            id=str(uuid.uuid4()),
            vector=vector,
            payload=metadata
        )
    )

# Step 5: Upsert into Qdrant
print(f"Uploading {len(points)} vectors to Qdrant...")
client.upsert(collection_name="ncert-vectors", points=points)

print("✅ Embeddings successfully loaded into Qdrant!")

# Clean up
conn.close()

# %%
import sqlite3
import json
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PointStruct
import numpy as np

# 1. Connect to SQLite
conn = sqlite3.connect("C:\\Users\\Srujana\\Documents\\edu-companion\\assets\\ncert-vectors.db")
cursor = conn.cursor()

# 2. Connect to Qdrant
client = QdrantClient(host="localhost", port=6333)

# 3. Create (or recreate) the collection in Qdrant
VECTOR_SIZE = 384  # Adjust if different
client.recreate_collection(
    collection_name="ncert-vectors",
    vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE)
)

# 4. Read rows from SQLite
cursor.execute("SELECT id, content, metadata, embedding FROM vectors")
rows = cursor.fetchall()

points = []

for row in rows:
    row_id, content, metadata_json, embedding_blob = row

    # Parse metadata
    metadata = json.loads(metadata_json)

    # Convert binary/vector to list of floats
    vector = np.frombuffer(embedding_blob, dtype=np.float32).tolist()

    # Create PointStruct
    points.append(
        PointStruct(
            id=row_id,
            vector=vector,
            payload={
                "content": content,
                **metadata  # unpack class, chapter, page, etc.
            }
        )
    )

# 5. Upload to Qdrant
print(f"Uploading {len(points)} vectors to Qdrant...")
client.upsert(collection_name="ncert-vectors", points=points)

print("✅ All vectors uploaded successfully!")

# Cleanup
conn.close()
# Out:
# C:\Users\Srujana\AppData\Local\Temp\ipykernel_6312\2944511802.py:16: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Uploading 206 vectors to Qdrant...
# ✅ All vectors uploaded successfully!

# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(
    url="https://1bcdfef2-22c6-44f9-a2fa-adc4a4ca5e4e.europe-west3-0.gcp.cloud.qdrant.io:6333", 
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.erRscERUav-m7n0_T5FbZkvCFakbTMlcuM5Rqu-Q038",
)

print(qdrant_client.get_collections())

# %%
import sqlite3
import json
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PointStruct
import numpy as np

# 1. Connect to SQLite
conn = sqlite3.connect("C:\\Users\\Srujana\\Desktop\\ncert-vectors.db")
cursor = conn.cursor()

# 2. Connect to Qdrant
client = QdrantClient(
    url="https://1bcdfef2-22c6-44f9-a2fa-adc4a4ca5e4e.europe-west3-0.gcp.cloud.qdrant.io:6333",
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.erRscERUav-m7n0_T5FbZkvCFakbTMlcuM5Rqu-Q038",
)

# 3. Create (or recreate) the collection in Qdrant
VECTOR_SIZE = 384  # Adjust if different
client.recreate_collection(
    collection_name="ncert-clas11-phy-vectors",
    vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE)
)

# 4. Read rows from SQLite
cursor.execute("SELECT id, content, metadata, embedding FROM vectors")
rows = cursor.fetchall()

points = []

for row in rows:
    row_id, content, metadata_json, embedding_blob = row

    # Parse metadata
    metadata = json.loads(metadata_json)

    # Convert binary/vector to list of floats
    vector = np.frombuffer(embedding_blob, dtype=np.float32).tolist()

    # Create PointStruct
    points.append(
        PointStruct(
            id=row_id,
            vector=vector,
            payload={
                "content": content,
                **metadata  # unpack class, chapter, page, etc.
            }
        )
    )

# 5. Upload to Qdrant
print(f"Uploading {len(points)} vectors to Qdrant...")
client.upsert(collection_name="ncert-clas11-phy-vectors", points=points)

print("✅ All vectors uploaded successfully!")

# Cleanup
conn.close()
# Out:
# C:\Users\Srujana\AppData\Local\Temp\ipykernel_6668\25302962.py:19: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Uploading 206 vectors to Qdrant...
# ✅ All vectors uploaded successfully!

# %%
COLLECTION_NAME = "ncert-vectors"
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient, models
# Ensure the embedding model is the same one used for uploading the vectors
EMBEDDING_MODEL_NAME = 'all-MiniLM-L6-v2'
VECTOR_SIZE = 384 # Should match your uploaded vectors

# --- 1. Initialize Qdrant Client and Embedding Model ---
print("Initializing Qdrant client for Qdrant Cloud...")
try:
    client = QdrantClient(
        url="https://1bcdfef2-22c6-44f9-a2fa-adc4a4ca5e4e.europe-west3-0.gcp.cloud.qdrant.io:6333",
        api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.erRscERUav-m7n0_T5FbZkvCFakbTMlcuM5Rqu-Q038",
    )
    # Test connection
    cluster_info = client.cluster_info()
    print(f"Connected to Qdrant Cloud. Cluster status: {cluster_info.status}")
    collection_info = client.get_collection(collection_name=COLLECTION_NAME)
    print(f"Collection '{COLLECTION_NAME}' exists. Points count: {collection_info.points_count}")

except Exception as e:
    print(f"Error connecting to Qdrant Cloud or accessing collection: {e}")
    print("Please ensure your Qdrant Cloud URL/API Key are correct and the collection exists.")
    exit()

print(f"Loading embedding model: {EMBEDDING_MODEL_NAME}...")
try:
    embedding_model = SentenceTransformer(EMBEDDING_MODEL_NAME)
    print("Embedding model loaded.")
except Exception as e:
    print(f"Error loading embedding model: {e}")
    print("Please ensure 'sentence-transformers' is installed and the model name is correct.")
    exit()

# --- 2. Query Function ---

def run_query(query_text, top_k=5, filter_criteria=None):
    """
    Performs a semantic search query against the Qdrant Cloud collection.

    Args:
        query_text (str): The natural language query string.
        top_k (int): The number of top relevant results to return.
        filter_criteria (dict, optional): A dictionary of metadata filters.
                                           e.g., {"subject": "Physics", "class": "Class 11"}
    """
    print(f"\n--- Querying for: '{query_text}' ---")

    # Generate the vector embedding for the query text
    query_vector = embedding_model.encode(query_text).tolist()

    search_params = {
        "collection_name": COLLECTION_NAME,
        "query_vector": query_vector,
        "limit": top_k, # How many results to return
        "with_payload": True, # Return the payload (metadata + content)
        "with_vectors": False # No need to return the vectors themselves for typical search display
    }

    if filter_criteria:
        # Construct Qdrant filter from the dictionary
        qdrant_filter = models.Filter(
            must=[
                models.FieldCondition(
                    key=key,
                    match=models.MatchValue(value=value)
                ) for key, value in filter_criteria.items()
            ]
        )
        search_params["query_filter"] = qdrant_filter

    try:
        hits = client.search(**search_params)

        if not hits:
            print("No results found for this query or filter combination.")
            return

        print(f"Found {len(hits)} results:")
        for i, hit in enumerate(hits):
            print(f"\nResult {i+1} (Score: {hit.score:.4f}):")

            # Safely get payload values with default 'N/A'
            # Assuming your payload has 'content' and then 'class', 'subject', 'chapter', 'page'
            # based on your SQLite upload script.
            class_val = hit.payload.get('class', 'N/A')
            subject_val = hit.payload.get('subject', 'N/A')
            chapter_val = hit.payload.get('chapter', 'N/A')
            page_val = hit.payload.get('page', 'N/A')
            full_content_val = hit.payload.get('content', 'N/A') # Your payload stores it as 'content'

            print(f"  Class: {class_val}")
            print(f"  Subject: {subject_val}")
            print(f"  Chapter: {chapter_val}")
            print(f"  Page: {page_val}")
            print(f"  Content Snippet: {full_content_val[:300]}...") # Show first 300 chars

    except Exception as e:
        print(f"An error occurred during search: {e}")
        print("Please check your Qdrant Cloud connection, collection name, and ensure payload keys match.")

# --- Example Queries ---

# Basic semantic search (general query across all subjects)
run_query("third law of motion. To every action, there is always an equal andopposite reaction.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Srujana\anaconda3\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 COLLECTION_NAME = "ncert-vectors"
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 from qdrant_client import QdrantClient, models
#       4 # Ensure the embedding model is the same one used for uploading the vectors
#
# File c:\Users\Srujana\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
# ...

# %%
pip install tf-keras
# Out:
# ...
#   Obtaining dependency information for tf-keras from https://files.pythonhosted.org/packages/45/6b/d245122d108a94df5969ee7408ad343af1627730e91478e01ef098976bfa/tf_keras-2.19.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tensorflow<2.20,>=2.19 from https://files.pythonhosted.org/packages/3c/e3/e868f1d5951047f950d2ba1e04a765a3328a51f06996b67976d6102f8227/tensorflow-2.19.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for flatbuffers>=24.3.25 from https://files.pythonhosted.org/packages/b8/25/155f9f080d5e4bc0082edfda032ea2bc2b8fab3f4d25d46c1e9dd22a1a89/flatbuffers-25.2.10-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tensorboard~=2.19.0 from https://files.pythonhosted.org/packages/5d/12/4f70e8e2ba0dbe72ea978429d8530b0333f0ed2140cc571a48802878ef99/tensorboard-2.19.0-py3-none-any.whl.metadata
# ...

# %%
pip install sentence-transformers
# Out:
# ...
#   Obtaining dependency information for sentence-transformers from https://files.pythonhosted.org/packages/6f/ff/178f08ea5ebc1f9193d9de7f601efe78c01748347875c8438f66f5cecc19/sentence_transformers-5.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for transformers<5.0.0,>=4.41.0 from https://files.pythonhosted.org/packages/96/88/beb33a79a382fcd2aed0be5222bdc47f41e4bfe7aaa90ae1374f1d8ea2af/transformers-4.53.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/40.9 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.9 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/40.9 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 40.9/40.9 kB 278.8 kB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Replace 'VIDEO_ID' with the actual YouTube video ID (the part after v= in a YouTube link)
video_id = "-QTkPfq7w1A"

# Fetch the transcript as a list of dictionaries
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# Print or process the transcript
for line in transcript:
    print(f"[{line['start']:.2f}s - {line['start'] + line['duration']:.2f}s] {line['text']}")
# Out:
# [0.24s - 4.56s] This little mechanism shrinks when you
# [2.48s - 6.64s] try to stretch it. You try to pull it
# [4.56s - 10.08s] apart and all of a sudden it pulls back
# [6.64s - 11.92s] on you. That's so weird, right? Here it
# [10.08s - 14.16s] is under controlled conditions. There's
# [11.92s - 16.00s] a cup hanging from the mechanism. But
# [14.16s - 18.40s] now look what happens as you add water
# [16.00s - 21.28s] to it. All of a sudden, the cup shoots
# [18.40s - 22.64s] up. The amount it shoots up is tiny. But
# [21.28s - 25.12s] the physics behind it is so
# [22.64s - 26.88s] counterintuitive, nobody thought it was
# [25.12s - 29.04s] possible. It feels like it violates
# [26.88s - 30.88s] physics. That's why it's fun. The
# [29.04s - 32.72s] paradox that controls this mechanism
# [30.88s - 35.20s] governs everything from mechanical
# [32.72s - 37.76s] systems to food chains, from traffic
# [35.20s - 39.76s] jams to power grids. And to understand
# ...

# %%
pip install youtube-transcript-api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
